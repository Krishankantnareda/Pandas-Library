# %%
import pandas as pd

# %% [raw]
# Pandas always works with the stucture data
# if your data is unsturctured then you can't be able to perform any pandas based opretion

# %%
data = pd.read_csv("addresses.csv")

# %%
data
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [raw]
# The Type of the data is DataFrame
# so DataFreme is the data type which is avalible inside a pandas lybrery
# By Default whenever pandas is trying to read any file
# whether you have excel sheet json csv
# from every file it is converting into datafreme

# %%
# if i want to read only first 5 lines of data 
# so by default head is trying to take first 5 raw 

data.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %% [raw]
# whenever pandas will read your file it will read first line as a heding or a colum name

# %%
data.head(7)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
# 5   6            6      800 Middle Avenue       NaN    Menlo Park
# 6   7            7         500 Arbor Road       NaN    Menlo Park
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US
# 5             CA  94025-9881      US
# 6             CA       94025      US

# %%
data.tail()
# Out:
#     id  location_id                   address_1  address_2  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
data.tail(8)
# Out:
#     id  location_id                   address_1  address_2  \
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# 15  16           16         1161 South Bernardo        NaN
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 13         Redwood City             CA       94063      US
# 14        San Francisco             CA       94110      US
# 15            Sunnyvale             CA       94087      US
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# ...

# %%
data.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['id',
#  'location_id',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %%
data.head(3)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US

# %%
data[["id" , "address_1"]]
# Out:
#     id                   address_1
# 0    1       2600 Middlefield Road
# 1    2            24 Second Avenue
# 2    3            24 Second Avenue
# 3    4            24 Second Avenue
# 4    5            24 Second Avenue
# 5    6           800 Middle Avenue
# 6    7              500 Arbor Road
# 7    8           800 Middle Avenue
# 8    9       2510 Middlefield Road
# 9   10       1044 Middlefield Road
# 10  11         2140 Euclid Avenue.
# 11  12       1044 Middlefield Road
# 12  13         399 Marine Parkway.
# 13  14          660 Veterans Blvd.
# 14  15        1500 Valencia Street
# 15  16         1161 South Bernardo
# 16  17     409 South Spruce Avenue
# 17  18            114 Fifth Avenue
# 18  19         19 West 39th Avenue
# 19  20          123 El Camino Real
# 20  21  2013 Avenue of the fellows

# %%
data[["city" , "state_province"]]
# Out:
#                    city state_province
# 0          Redwood City             CA
# 1             San Mateo             CA
# 2             San Mateo             CA
# 3             San Mateo             CA
# 4             San Mateo             CA
# 5            Menlo Park             CA
# 6            Menlo Park             CA
# 7            Menlo Park             CA
# 8          Redwood City             CA
# 9          Redwood City             CA
# 10         Redwood City             CA
# 11         Redwood City             CA
# 12         Redwood City             CA
# 13         Redwood City             CA
# 14        San Francisco             CA
# 15            Sunnyvale             CA
# 16  South San Francisco             CA
# 17         Redwood City             CA
# 18            San Mateo             CA
# 19              Belmont             CA
# 20        San Francisco             CA

# %%
data["city"]
# Out:
# 0            Redwood City
# 1               San Mateo
# 2               San Mateo
# 3               San Mateo
# 4               San Mateo
# 5              Menlo Park
# 6              Menlo Park
# 7              Menlo Park
# 8            Redwood City
# 9            Redwood City
# 10           Redwood City
# 11           Redwood City
# 12           Redwood City
# 13           Redwood City
# 14          San Francisco
# 15              Sunnyvale
# 16    South San Francisco
# 17           Redwood City
# 18              San Mateo
# 19                Belmont
# 20          San Francisco
# Name: city, dtype: object

# %%
#but if i am not using this list
data["city" , "state_province"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('city', 'state_province')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
type(data["city"])
# Out:
# pandas.core.series.Series

# %%
type(data[["city" , "state_province"]])
# Out:
# pandas.core.frame.DataFrame

# %% [raw]
# Series is nothing but it is a subset of dataframe
# and dataframe is nothing but it is a just a collection of series you can say
# and you can't use multiple colums in a series data type

# %%
pd.read_excel("airline (2).xls")
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %% [raw]
# # if i have mutiple sheets in a single Xls file and
# i want only sheet 1 data than how its works ! see

# %%
pd.read_excel("airline1 (1).xls")
# by default it will go to your first sheet in your file 
# but what if you want to read sheet no 2.
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
pd.read_excel("airline1 (1).xls" , sheet_name = "Sheet2")
# Out:
#    YEAR      Y      W       R      L      K
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574
# 5  1953  2.731  0.322  0.3593  1.926  0.711
# 6  1954  3.025  0.335  0.4025  1.964  0.776
# 7  1955  3.562  0.350  0.3961  2.116  0.827
# 8  1956  3.979  0.361  0.3822  2.435  0.800

# %%
pd.read_excel("airline1 (1).xls" , sheet_name = "Sheet3")
# in this Sheet 3 there is no coulum name 
# but now pandas is considring as a coulum name 
# how i able to resolve it
# Out:
#     1960.0000  5.5540     0.4410     0.3193     3.0890     1.4810
# 0        1961      5.465      0.460     0.3079      3.122      1.736
# 1        1962      5.825      0.485     0.3783      3.184      1.926
# 2        1963      6.876      0.506     0.4180      3.263      2.041
# 3        1964      7.823      0.538     0.5163      3.412      1.997
# 4        1965      9.120      0.564     0.5879      3.623      2.257
# 5        1966     10.512      0.586     0.5369      4.074      2.742
# 6        1967     13.020      0.622     0.4443      4.710      3.564
# 7        1968     15.261      0.666     0.3052      5.217      4.767
# 8        1969     16.313      0.731     0.2332      5.569      6.511
# 9        1970     16.002      0.831     0.1883      5.495      7.627
# 10       1971     15.876      0.906     0.2023      5.334      8.673
# 11       1972     16.662      1.000     0.2506      5.345      8.331
# 12       1973     17.014      1.056     0.2668      5.662      8.557
# ...

# %%
pd.read_excel("airline1 (1).xls" , sheet_name = "Sheet2" , header = None )
# Out:
#       0      1      2       3      4      5
# 0  YEAR      Y      W       R      L      K
# 1  1948  1.214  0.243  0.1454  1.415  0.612
# 2  1949  1.354   0.26  0.2181  1.384  0.559
# 3  1950  1.569  0.278  0.3157  1.388  0.573
# 4  1951  1.948  0.297   0.394   1.55  0.564
# 5  1952  2.265   0.31  0.3559  1.802  0.574
# 6  1953  2.731  0.322  0.3593  1.926  0.711
# 7  1954  3.025  0.335  0.4025  1.964  0.776
# 8  1955  3.562   0.35  0.3961  2.116  0.827
# 9  1956  3.979  0.361  0.3822  2.435    0.8

# %%
# Now if i want to use my own custum colum name
pd.read_excel("airline1 (1).xls" , sheet_name = "Sheet2" , names= ["kri","ir","ewif","jsi","iseof","sei"] )
# Out:
#     kri     ir   ewif     jsi  iseof    sei
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574
# 5  1953  2.731  0.322  0.3593  1.926  0.711
# 6  1954  3.025  0.335  0.4025  1.964  0.776
# 7  1955  3.562  0.350  0.3961  2.116  0.827
# 8  1956  3.979  0.361  0.3822  2.435  0.800

# %%
# What if you only put 3 in names list 
pd.read_excel("airline1 (1).xls" , sheet_name = "Sheet2" , header = None , names= ["kri","ir","sei"] )
# Out:
#                      kri     ir    sei
# YEAR Y     W           R      L      K
# 1948 1.214 0.243  0.1454  1.415  0.612
# 1949 1.354 0.26   0.2181  1.384  0.559
# 1950 1.569 0.278  0.3157  1.388  0.573
# 1951 1.948 0.297   0.394   1.55  0.564
# 1952 2.265 0.31   0.3559  1.802  0.574
# 1953 2.731 0.322  0.3593  1.926  0.711
# 1954 3.025 0.335  0.4025  1.964  0.776
# 1955 3.562 0.35   0.3961  2.116  0.827
# 1956 3.979 0.361  0.3822  2.435    0.8

# %%
Data1 = pd.read_excel("airline1 (1).xls" , sheet_name = "Sheet2" , header = None , names= ["kri","ir","ewif","jsi","iseof","sei"] )

# %%
Data1
# IF i close this jupiter lab than i have to execute this Variable Data1 line than only i find this Data1
# Now i want to save This Data1 into file
# Out:
#     kri     ir   ewif     jsi  iseof    sei
# 0  YEAR      Y      W       R      L      K
# 1  1948  1.214  0.243  0.1454  1.415  0.612
# 2  1949  1.354   0.26  0.2181  1.384  0.559
# 3  1950  1.569  0.278  0.3157  1.388  0.573
# 4  1951  1.948  0.297   0.394   1.55  0.564
# 5  1952  2.265   0.31  0.3559  1.802  0.574
# 6  1953  2.731  0.322  0.3593  1.926  0.711
# 7  1954  3.025  0.335  0.4025  1.964  0.776
# 8  1955  3.562   0.35  0.3961  2.116  0.827
# 9  1956  3.979  0.361  0.3822  2.435    0.8

# %%
# To save this Data1 into file We have 
Data1.to_csv("Kri.csv")

# %%
Data1.to_csv("Kri") # you need to use .csv while you given your fle name
# Atherwise it will be considering as a txt file

# %%
# Now if you see in your csv file indexing was also stored
# so we have provision to remove this 
Data1.to_csv("Kri.csv" , index = False)
# Now if you see indexes was gone

# %%
Data1.to_excel("New.xlsx")

# %%
# ones It will load a data

# %%
krishan = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
krishan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
# When we are using read_html it will only read the data which is in the form of table
# if you don't have any kind of table inside your website it will not be able to fatch any kind of data
# and the read_html will give you data in the list form becouse there is a possibility you have more than 1 table in your website

# %%
data2 = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
# it is not readable as it shown as in website
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 data2 = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
# ...

# %%
# if i want to fatch the website data then We go 
data2 = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [45], line 2
#       1 # if i want to fatch the website data then We go
# ----> 2 data2 = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
type(data2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [47], line 1
# ----> 1 type(data2)
#
# NameError: name 'data2' is not defined

# %%
len(data2)

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data2[0]
# it is showing as show as in website
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [49], line 1
# ----> 1 data2[0]
#
# NameError: name 'data2' is not defined

# %%
#if i want to insert this data into csv file 
data2[0].to_csv("Players.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [50], line 2
#       1 #if i want to insert this data into csv file
# ----> 2 data2[0].to_csv("Players.csv")
#
# NameError: name 'data2' is not defined
