# %%
import pandas as pd

# %%
pd.read_csv("addresses.csv")
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
# This is the tytenic dataset 
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail(6)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 885  female  39.0      0      5      382652  29.125   NaN        Q
# 886    male  27.0      0      0      211536  13.000   NaN        S
# 887  female  19.0      0      0      112053  30.000   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.450   NaN        S
# 889    male  26.0      0      0      111369  30.000  C148        C
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.to_excel("tytanic.xlsx")

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [raw]
# # But if i want to describe the categorical dataset
# # so to this i first i need to know about how many columns we have in our dataset which is having Categorical data
#  To Fatch the categorical data

# %%
data[["Name", "Sex" , "Ticket"]]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# ...

# %%
data[["Name", "Sex" , "Ticket"]].describe()
# Out:
#                            Name   Sex  Ticket
# count                       891   891     891
# unique                      891     2     681
# top     Braund, Mr. Owen Harris  male  347082
# freq                          1   577       7

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(data.dtypes)
# We can say Pandas Series is almost eqvalent to a list
# Out:
# pandas.core.series.Series

# %%
# In series it will always gives you index
data["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %% [raw]
# I Want only this dataType where type is object

# %%
data.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data.dtypes[data.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
type(data.dtypes[data.dtypes == "object"])
# Out:
# pandas.core.series.Series

# %% [raw]
# If i want this as a list where index data was object

# %%
data.dtypes[data.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
data[data.dtypes[data.dtypes == "object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
data[data.dtypes[data.dtypes == "object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data[data.dtypes[data.dtypes == "int64"].index].describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.523008    0.381594
# std     257.353842    0.486592    0.836071    1.102743    0.806057
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000    0.000000
# 50%     446.000000    0.000000    3.000000    0.000000    0.000000
# 75%     668.500000    1.000000    3.000000    1.000000    0.000000
# max     891.000000    1.000000    3.000000    8.000000    6.000000

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [raw]
# Now if i want Survived column where data was 0

# %%
data[data["Survived"] == 0 ].head(3)
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 0            1         0       3   Braund, Mr. Owen Harris  male  22.0      1
# 4            5         0       3  Allen, Mr. William Henry  male  35.0      0
# 5            6         0       3          Moran, Mr. James  male   NaN      0
#
#    Parch     Ticket    Fare Cabin Embarked
# 0      0  A/5 21171  7.2500   NaN        S
# 4      0     373450  8.0500   NaN        S
# 5      0     330877  8.4583   NaN        Q

# %% [raw]
# Now i want those data where Survived is 0 and sex was male

# %%
data[(data["Survived"] == 0) & (data["Sex"] == "male")]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data[(data["Survived"] == 0) & (data["Sex"] == "male")].count()
# Out:
# PassengerId    468
# Survived       468
# Pclass         468
# Name           468
# Sex            468
# Age            360
# SibSp          468
# Parch          468
# Ticket         468
# Fare           468
# Cabin           62
# Embarked       468
# dtype: int64

# %%
len(data[(data["Survived"] == 0) & (data["Sex"] == "male")])
# Out:
# 468

# %% [raw]
# So based on this we can make a statement that
# out of 891 passenger 468 male passenger has died

# %% [raw]
# Now similer thing we can do with the female side as well

# %%
len(data[(data["Survived"] == 0) & (data["Sex"] == "female")])
# Out:
# 81

# %%
data[(data["Survived"] == 0) & (data["Sex"] == "female")].count()
# Out:
# PassengerId    81
# Survived       81
# Pclass         81
# Name           81
# Sex            81
# Age            64
# SibSp          81
# Parch          81
# Ticket         81
# Fare           81
# Cabin           6
# Embarked       81
# dtype: int64

# %%
len(data[(data["Survived"] == 0) & (data["Sex"] == "female")].count())
# Out:
# 12

# %% [raw]
# Now we can make a statement that only 81 female was died out of the 891 passengers

# %% [raw]
# Number of male on the ship
# Number of female on the ship

# %%
len(data[(data["Survived"] == 1) & (data["Sex"] == "female")])
# Out:
# 233

# %%
len(data[(data["Survived"] == 1) & (data["Sex"] == "male")])
# Out:
# 109

# %%
data["Sex"].value_counts()
# it will group by
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
len(data[data["Sex"] == "male"])
# Out:
# 577

# %%
len(data[data["Sex"] == "female"])
# Out:
# 314

# %% [raw]
# Name of the person who was paid highest Fare for Ticket

# %%
max(data["Fare"])
# it is a series and we know it that series is almost like an list so 
# we can use max fuctiion over there
# Out:
# 512.3292

# %%
data[data["Fare"] == max(data["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %% [raw]
# So we can make a decison that who was paying more money for Fare
# the person was survived in this incident

# %%
# if i want to know Name of the person
data[data["Fare"] == max(data["Fare"])]["Name"]
# Now it a series
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %% [raw]
# If i want ans i a DataFreme for better Visulyzation

# %%
data[data["Fare"] == max(data["Fare"])][["Name"]]
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %% [raw]
# Same thing we can do with Min Amount of Fare as well

# %%
data[data["Fare"] == min(data["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
len(data[data["Fare"] == min(data["Fare"])])
# Out:
# 15

# %% [raw]
# So there is only one person who was servived with spending 0 money for Fare out of the 15 person

# %% [raw]
# Now i want people who has Allotted cabin

# %%
data[data["Cabin"] == "NaN"]# Not be able to Found it
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data["Cabin"].isnull()
# isnull will Give you record as a True or False
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
data[data["Cabin"].isnull() == False]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(data[data["Cabin"].isnull() == False])
# Out:
# 204

# %% [raw]
# So there are only 204 people was having a Cabin Facelity out of the 891

# %% [raw]
# Now if i want to Add a new column inside my data

# %%
data["New_col"] = "Krishan"

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_col
# 0      0         A/5 21171   7.2500   NaN        S  Krishan
# 1      0          PC 17599  71.2833   C85        C  Krishan
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Krishan
# 3      0            113803  53.1000  C123        S  Krishan
# ...

# %%
#If i want to create a dublicate column
data["New_Name"] = data["Name"]

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  New_col  \
# 0      0  A/5 21171   7.2500   NaN        S  Krishan
# 1      0   PC 17599  71.2833   C85        C  Krishan
#
#                                             New_Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...

# %% [raw]
# Now if i have to create a New Column which is having addition of Age and Pclass column

# %%
data["Age_Pclass"] = data["Age"] + data["Pclass"]

# %%
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_col  \
# 0      0         A/5 21171   7.2500   NaN        S  Krishan
# 1      0          PC 17599  71.2833   C85        C  Krishan
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Krishan
#
#                                             New_Name  Age_Pclass
# 0                            Braund, Mr. Owen Harris        25.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        39.0
# 2                             Heikkinen, Miss. Laina        29.0

# %%
#del(data["New_col"])

# %% [raw]
# When we use drop command to drop a column or a row than we need to keep in mind is we have to call axis over there
# and axis is Zero 0 for Row indexes and axis = 1 for Column indexes

# %%
data.drop("New_col") # Getting Error becouse axis is 0
# There is no index in a Row "New_col"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [54], line 1
# ----> 1 data.drop("New_col")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:5388, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5240 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5241 def drop(  # type: ignore[override]
#    5242     self,
#    (...)
# ...

# %%
data.drop("New_col" , axis = 1).head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
#
#                                             New_Name  Age_Pclass
# 0                            Braund, Mr. Owen Harris        25.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        39.0
# 2                             Heikkinen, Miss. Laina        29.0

# %% [raw]
# when we use drop method to drop column
# it is not deleted permanently , so to deal this kind of situvation we have another parameter called as inplace
# By default inplace is set to False we need to custmize it to (" True")
#
# or we can use reassingment also

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  New_col  \
# 0      0  A/5 21171   7.2500   NaN        S  Krishan
# 1      0   PC 17599  71.2833   C85        C  Krishan
#
#                                             New_Name  Age_Pclass
# 0                            Braund, Mr. Owen Harris        25.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        39.0

# %%
data.drop("New_col" ,axis = 1, inplace = True)

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  \
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
#
#                                             New_Name  Age_Pclass
# 0                            Braund, Mr. Owen Harris        25.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        39.0

# %%
del(data["New_Name"])

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Age_Pclass
# 0      0  A/5 21171   7.2500   NaN        S        25.0
# 1      0   PC 17599  71.2833   C85        C        39.0

# %%
#  If i want to delete Row index 

data.drop(0)
# it is not permanently deleted
data = data.drop(0)

# %% [raw]
# Can you please try to Fatch all the data which is in the first Row

# %%
data.iloc[0]  # it will be takin indexes internally so it will be getting record
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Age_Pclass                                                  39.0
# Name: 1, dtype: object

# %%
data.loc[1] # loc will be taking named indexes
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Age_Pclass                                                  39.0
# Name: 1, dtype: object

# %%
data.loc[2:4] # this is the named indexes which is i given
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket    Fare Cabin Embarked  Age_Pclass
# 2  STON/O2. 3101282   7.925   NaN        S        29.0
# 3            113803  53.100  C123        S        36.0
# 4            373450   8.050   NaN        S        38.0

# %%
data.iloc[2:4] # this is the internal indexes which is the
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#    Ticket   Fare Cabin Embarked  Age_Pclass
# 3  113803  53.10  C123        S        36.0
# 4  373450   8.05   NaN        S        38.0

# %%
data.loc[101:105,["Survived" , "Pclass"]]
# Out:
#      Survived  Pclass
# 101         0       3
# 102         0       1
# 103         0       3
# 104         0       3
# 105         0       3

# %%
data.loc[3:4 , ["Fare" , "Cabin" , "Embarked"]]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
data.iloc[3:4 , ["Fare" , "Cabin" , "Embarked"]] 
# becouse system has allocated internal indexes and it not like "Fare" it is in the foem of 3,5
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [70], line 1
# ----> 1 data.iloc[3:4 , ["Fare" , "Cabin" , "Embarked"]]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# ...

# %%
data.iloc[3:4 , [9,11,12]]
# Out:
#    Fare Embarked  Age_Pclass
# 4  8.05        S        38.0

# %%
data.loc[ [3,5] , ["Pclass" , "Survived","PassengerId"]]
# Out:
#    Pclass  Survived  PassengerId
# 3       1         1            4
# 5       3         0            6

# %%
type(data.iloc[ : ,[0,2]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(data.iloc[3:4,[0,2]])
# Out:
# pandas.core.frame.DataFrame

# %%
data[data["Age"] > 35]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1 = data.iloc[1:10 , [2,3,4,5,9,10]]

# %%
data1
# Out:
#     Pclass                                               Name     Sex   Age  \
# 2        3                             Heikkinen, Miss. Laina  female  26.0
# 3        1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4        3                           Allen, Mr. William Henry    male  35.0
# 5        3                                   Moran, Mr. James    male   NaN
# 6        1                            McCarthy, Mr. Timothy J    male  54.0
# 7        3                     Palsson, Master. Gosta Leonard    male   2.0
# 8        3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10       3                    Sandstrom, Miss. Marguerite Rut  female   4.0
#
#        Fare Cabin
# 2    7.9250   NaN
# 3   53.1000  C123
# 4    8.0500   NaN
# 5    8.4583   NaN
# 6   51.8625   E46
# 7   21.0750   NaN
# 8   11.1333   NaN
# 9   30.0708   NaN
# 10  16.7000    G6

# %% [raw]
# I want to chenge the Name of Row indexex

# %%
data1.set_index("Name",inplace=True)

# %%
data1
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123
# ...

# %%
# I want to delete the Row where cell having null values

data1.dropna()
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# McCarthy, Mr. Timothy J                            1    male  54.0  51.8625
# Sandstrom, Miss. Marguerite Rut                    3  female   4.0  16.7000
#
#                                              Cabin
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# McCarthy, Mr. Timothy J                        E46
# Sandstrom, Miss. Marguerite Rut                 G6

# %%
# I want to delete the column wherever having null values
data1.dropna(axis = 1)
# so we having null values in only in Age and Cabin
# Out:
#                                                    Pclass     Sex     Fare
# Name
# Heikkinen, Miss. Laina                                  3  female   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  53.1000
# Allen, Mr. William Henry                                3    male   8.0500
# Moran, Mr. James                                        3    male   8.4583
# McCarthy, Mr. Timothy J                                 1    male  51.8625
# Palsson, Master. Gosta Leonard                          3    male  21.0750
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  11.1333
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  30.0708
# Sandstrom, Miss. Marguerite Rut                         3  female  16.7000

# %%
data1.dropna(axis = 1 , thresh = 1) #  Require that many non-NA values 
# Means if my data having min 1 non - NA values than only it will be give you
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123
# ...

# %%
data1.dropna(axis = 1 , thresh = 9)
# Out:
#                                                    Pclass     Sex     Fare
# Name
# Heikkinen, Miss. Laina                                  3  female   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  53.1000
# Allen, Mr. William Henry                                3    male   8.0500
# Moran, Mr. James                                        3    male   8.4583
# McCarthy, Mr. Timothy J                                 1    male  51.8625
# Palsson, Master. Gosta Leonard                          3    male  21.0750
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  11.1333
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  30.0708
# Sandstrom, Miss. Marguerite Rut                         3  female  16.7000

# %%
data1.dropna(axis = 0 , thresh = 9)
# Out:
# Empty DataFrame
# Columns: [Pclass, Sex, Age, Fare, Cabin]
# Index: []

# %%
data1.dropna(axis = 0 , thresh = 5)
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# McCarthy, Mr. Timothy J                            1    male  54.0  51.8625
# Sandstrom, Miss. Marguerite Rut                    3  female   4.0  16.7000
#
#                                              Cabin
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# McCarthy, Mr. Timothy J                        E46
# Sandstrom, Miss. Marguerite Rut                 G6

# %%
data1.dropna(axis = 0 , thresh = 6)
# Out:
# Empty DataFrame
# Columns: [Pclass, Sex, Age, Fare, Cabin]
# Index: []

# %%
data1.fillna("Krishan") # it will fill values where We have null values
# Out:
#                                                    Pclass     Sex      Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female     26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female     35.0
# Allen, Mr. William Henry                                3    male     35.0
# Moran, Mr. James                                        3    male  Krishan
# McCarthy, Mr. Timothy J                                 1    male     54.0
# Palsson, Master. Gosta Leonard                          3    male      2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female     27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female     14.0
# Sandstrom, Miss. Marguerite Rut                         3  female      4.0
#
#                                                       Fare    Cabin
# Name
# Heikkinen, Miss. Laina                              7.9250  Krishan
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000     C123
# ...

# %%
# if i want to fill the null values with the Averge of Age 
data1.fillna(data["Age"].mean())
# Out:
#                                                    Pclass     Sex        Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.000000
# Allen, Mr. William Henry                                3    male  35.000000
# Moran, Mr. James                                        3    male  29.709916
# McCarthy, Mr. Timothy J                                 1    male  54.000000
# Palsson, Master. Gosta Leonard                          3    male   2.000000
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.000000
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.000000
# Sandstrom, Miss. Marguerite Rut                         3  female   4.000000
#
#                                                       Fare      Cabin
# Name
# Heikkinen, Miss. Laina                              7.9250  29.709916
# ...

# %%
data1.groupby("Sex").count()
# Out:
#         Pclass  Age  Fare  Cabin
# Sex
# female       5    5     5      2
# male         4    3     4      1

# %%
data1.groupby("Sex").mean()
# This is not the Error this is FutureWarning
# Out:
# /tmp/ipykernel_84/23835206.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1.groupby("Sex").mean()
#         Pclass        Age      Fare
# Sex
# female     2.4  21.200000  23.78582
# male       2.5  30.333333  22.36145

# %%
data1.groupby("Sex").mean()["Age"]
# Out:
# /tmp/ipykernel_84/3637869686.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1.groupby("Sex").mean()["Age"]
# Sex
# female    21.200000
# male      30.333333
# Name: Age, dtype: float64

# %% [raw]
# What is a total Fare paid by Female and
# What was the total Fare Paid by Male

# %%
data1
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123
# ...

# %%
data1.groupby("Sex").sum()["Fare"]
# it is given  me warning becaouse we have categorical dataset a
# and we are using sum operation so how will be able to do that
# Out:
# /tmp/ipykernel_84/2920499169.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1.groupby("Sex").sum()["Fare"]
# Sex
# female    118.9291
# male       89.4458
# Name: Fare, dtype: float64

# %%
data1
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123
# ...

# %%
data2 = data.iloc[0:4 , 0:5]

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %% [raw]
# Now we have data1 and data2
# My requirement is to merge both of the data's
# Merge Horizontally or Merge Vertically

# %% [raw]
# See how can i concatinate 2 or more than 2 data's

# %%
pd.concat([data1,data2])
# This is the vartical concatination
# Out:
#                                                    Pclass     Sex   Age  \
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
# 1                                                       1  female   NaN
# 2                                                       3  female   NaN
# 3                                                       1  female   NaN
# ...

# %%
pd.concat([data1,data2] , axis=1)
# Out:
#                                                    Pclass     Sex   Age  \
# Heikkinen, Miss. Laina                                3.0  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)          1.0  female  35.0
# Allen, Mr. William Henry                              3.0    male  35.0
# Moran, Mr. James                                      3.0    male   NaN
# McCarthy, Mr. Timothy J                               1.0    male  54.0
# Palsson, Master. Gosta Leonard                        3.0    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     3.0  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                   2.0  female  14.0
# Sandstrom, Miss. Marguerite Rut                       3.0  female   4.0
# 1                                                     NaN     NaN   NaN
# 2                                                     NaN     NaN   NaN
# 3                                                     NaN     NaN   NaN
# ...

# %%
data1["New_div_3"] = data1["Pclass"].apply(lambda v : v/3)

# %%
data1
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin  New_div_3
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN   1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123   0.333333
# ...

# %%
def fuc1(x):
    return x/3

# %%
data1["New_own_fuc"] = data1["Pclass"].apply(fuc1)

# %%
data1
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin  New_div_3  \
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN   1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123   0.333333
# ...

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
data2["New_Len"] = data2["Name"].apply(lambda x : len(x))

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  New_Len
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female       51
# 2                             Heikkinen, Miss. Laina  female       22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       44
# 4                           Allen, Mr. William Henry    male       24

# %%
def fuc2(v):
    return len(v)

# %%
data2["New_Len_own"] = data2["Name"].apply(fuc2)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  New_Len  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female       51
# 2                             Heikkinen, Miss. Laina  female       22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       44
# 4                           Allen, Mr. William Henry    male       24
#
#    New_Len_own
# 1           51
# 2           22
# 3           44
# 4           24

# %% [raw]
# My problam Statement is
# In date2 Passengerid Column if data is less than 3 than give me as it is and,
# If data is greater than or equal to 3 than return me logeretmic data of data

# %%
def fuc3(x):
    import math as kri
    if x<3:
        return x
    else:
        return kri.log10(x)

# %%
data2["LOG_New"] = data2["PassengerId"].apply(fuc3)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  New_Len  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female       51
# 2                             Heikkinen, Miss. Laina  female       22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       44
# 4                           Allen, Mr. William Henry    male       24
#
#    New_Len_own   LOG_New
# 1           51  2.000000
# 2           22  0.477121
# 3           44  0.602060
# 4           24  0.698970

# %%
def fuc4(x):
    import math as kri
    if x<15:
        return x
    else:
        return kri.log10(x)

# %%
data1["log"] = data1["Fare"].apply(fuc4())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [122], line 1
# ----> 1 data1["log"] = data1["Fare"].apply(fuc4())
#
# TypeError: fuc4() missing 1 required positional argument: 'x'

# %%
data1
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin  New_div_3  \
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN   1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123   0.333333
# ...

# %% [raw]
# Try to create New colume in data1 which will give me 1 for male and 0 for female

# %%
def test(x):
    if x == "female":
        return 0 
    else :
        return 1

# %%
data1["M1F0"] = data1["Sex"].apply(test)

# %%
data1
# Out:
#                                                    Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                                  3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1  female  35.0
# Allen, Mr. William Henry                                3    male  35.0
# Moran, Mr. James                                        3    male   NaN
# McCarthy, Mr. Timothy J                                 1    male  54.0
# Palsson, Master. Gosta Leonard                          3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                     2  female  14.0
# Sandstrom, Miss. Marguerite Rut                         3  female   4.0
#
#                                                       Fare Cabin  New_div_3  \
# Name
# Heikkinen, Miss. Laina                              7.9250   NaN   1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       53.1000  C123   0.333333
# ...

# %%
data.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %% [raw]
# My requirment was fill NaN values In Age column with the Average of Age

# %% [raw]
# Why i am not suppuse to take Fillna fuction Becaouse Fillna will take all the data and Fill where Value is None
# insted apply will be able to take only one single column over there

# %% [raw]
# I need to group by The Fare ammount and return With Categri wise "A", "B ", "C"

# %%
def test4(c):
    if c<50:
        return "C"
    elif c<101:
        return "B"
    else :
        return "A"

# %%
data["Fare_Cat"] = data["Fare"].apply(test4)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(data [data["Fare"] >99 ])
# Out:
# 53
