# %%
d1 = {"Key1" : [1,2,3,4,5,6],
      "Key2" : [7,8,9,10,11,12],
      "Key3" : [13,14,15,16,17,18],
      "Key4" : [19,20,21,22,23,24]
     }

# %%
type(d1)
# Out:
# dict

# %% [raw]
# Can you plz Try to convert This dict in a DataFrame

# %%
import pandas as pd

# %%
pd.DataFrame(d1)
# Out:
#    Key1  Key2  Key3  Key4
# 0     1     7    13    19
# 1     2     8    14    20
# 2     3     9    15    21
# 3     4    10    16    22
# 4     5    11    17    23
# 5     6    12    18    24

# %% [raw]
# If i have one key in my dict which is having less values compare to author key's

# %%
d1 = {"Key1" : [1,2,3,5,6],
      "Key2" : [7,8,9,10,11,12],
      "Key3" : [13,14,15,16,17,18],
      "Key4" : [19,20,21,22,23,24]
     }

# %%
pd.DataFrame(d1) 
# It will giving me this ValueError  
#ValueError: All arrays must be of the same length
# you can not be able to make DataFrame with this kind of thing
# Out:
#    Key1  Key2  Key3  Key4
# 0     1     7    13    19
# 1     2     8    14    20
# 2     3     9    15    21
# 3     4    10    16    22
# 4     5    11    17    23
# 5     6    12    18    24

# %%
d2 = {"Key1" : [1,2,3,"Krishan",5,6],
      "Key2" : [7,8,"Vishnu",10,11,12],
      "Key3" : [13,14,15,16,17,"Ankit"],
      "Key4" : ["Hrithik",20,21,22,23,"Honey"]
     }

# %%
Df1 = pd.DataFrame(d1 , index=["a","b","c","d","e","f"])

# %%
Df2 = pd.DataFrame(d2)

# %%
Df1
# Out:
#    Key1  Key2  Key3  Key4
# a     1     7    13    19
# b     2     8    14    20
# c     3     9    15    21
# d     4    10    16    22
# e     5    11    17    23
# f     6    12    18    24

# %%
Df2
# Out:
#       Key1    Key2   Key3     Key4
# 0        1       7     13  Hrithik
# 1        2       8     14       20
# 2        3  Vishnu     15       21
# 3  Krishan      10     16       22
# 4        5      11     17       23
# 5        6      12  Ankit    Honey

# %%
pd.merge(Df2,Df1)  # This is Inner Merge opretiion
# By Default it will going to use inner: 
#  use intersection of keys from both frames
#  preserve the order of the left keys.
# Out:
#   Key1 Key2 Key3 Key4
# 0    2    8   14   20
# 1    5   11   17   23

# %%
pd.merge(Df1,Df2 , how= "inner" , on= "Key1")
# Out:
#   Key1  Key2_x  Key3_x  Key4_x  Key2_y Key3_y   Key4_y
# 0    1       7      13      19       7     13  Hrithik
# 1    2       8      14      20       8     14       20
# 2    3       9      15      21  Vishnu     15       21
# 3    5      11      17      23      11     17       23
# 4    6      12      18      24      12  Ankit    Honey

# %% [raw]
# Left join will only give you left dataframe as it is and show it to you
# while mergeing dataframe's if we are calling on with any perticuler column name it will check whether column values are same or not in
# both of the dataframe's if column values is same than it will give you left & right DataFrame column values as it is
#
# if there is diff between value's of column than this join will give you left dataframe Row value same and right Dataframe
# row values as  ---->>>.      NaN

# %%
pd.merge(Df2,Df1 , how= "left" , on= "Key4")
# Out:
#     Key1_x  Key2_x Key3_x     Key4  Key1_y  Key2_y  Key3_y
# 0        1       7     13  Hrithik     NaN     NaN     NaN
# 1        2       8     14       20     2.0     8.0    14.0
# 2        3  Vishnu     15       21     3.0     9.0    15.0
# 3  Krishan      10     16       22     4.0    10.0    16.0
# 4        5      11     17       23     5.0    11.0    17.0
# 5        6      12  Ankit    Honey     NaN     NaN     NaN

# %%
pd.merge(Df2,Df1 , how= "right" , on= "Key4")
# Out:
# /tmp/ipykernel_329/3132913880.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.merge(Df2,Df1 , how= "right" , on= "Key4")
#     Key1_x  Key2_x Key3_x  Key4  Key1_y  Key2_y  Key3_y
# 0      NaN     NaN    NaN  19.0       1       7      13
# 1        2       8     14  20.0       2       8      14
# 2        3  Vishnu     15  21.0       3       9      15
# 3  Krishan      10     16  22.0       4      10      16
# 4        5      11     17  23.0       5      11      17
# 5      NaN     NaN    NaN  24.0       6      12      18

# %%
pd.merge(Df1,Df2 , how= "left" , on= "Key4")
# Out:
#    Key1_x  Key2_x  Key3_x Key4   Key1_y  Key2_y Key3_y
# 0       1       7      13   19      NaN     NaN    NaN
# 1       2       8      14   20        2       8     14
# 2       3       9      15   21        3  Vishnu     15
# 3       4      10      16   22  Krishan      10     16
# 4       5      11      17   23        5      11     17
# 5       6      12      18   24      NaN     NaN    NaN

# %% [raw]
# Outer is a complete pakage you can say which will going to combain all the join's Like "ineer" , "left", "right" and show it to you

# %% [raw]
# Whenever you trying to do a merge operetion so then ON wise you can give multiple Key's also "in the from of List"

# %%
Df1
# Out:
#    Key1  Key2  Key3  Key4
# a     1     7    13    19
# b     2     8    14    20
# c     3     9    15    21
# d     4    10    16    22
# e     5    11    17    23
# f     6    12    18    24

# %%
Df2
# Out:
#       Key1    Key2   Key3     Key4
# 0        1       7     13  Hrithik
# 1        2       8     14       20
# 2        3  Vishnu     15       21
# 3  Krishan      10     16       22
# 4        5      11     17       23
# 5        6      12  Ankit    Honey

# %%
pd.merge(Df1,Df2 , how= "outer" , on= ["Key4" , "Key2"])
# Out:
# /tmp/ipykernel_329/2860997139.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.merge(Df1,Df2 , how= "outer" , on= ["Key4" , "Key2"])
#    Key1_x    Key2  Key3_x     Key4   Key1_y Key3_y
# 0     1.0     7.0    13.0     19.0      NaN    NaN
# 1     2.0     8.0    14.0     20.0        2     14
# 2     3.0     9.0    15.0     21.0      NaN    NaN
# 3     4.0    10.0    16.0     22.0  Krishan     16
# 4     5.0    11.0    17.0     23.0        5     17
# 5     6.0    12.0    18.0     24.0      NaN    NaN
# 6     NaN       7     NaN  Hrithik        1     13
# 7     NaN  Vishnu     NaN       21        3     15
# 8     NaN      12     NaN    Honey        6  Ankit

# %%
Df1
# Out:
#    Key1  Key2  Key3  Key4
# a     1     7    13    19
# b     2     8    14    20
# c     3     9    15    21
# d     4    10    16    22
# e     5    11    17    23
# f     6    12    18    24

# %%
Df2
# Out:
#       Key1    Key2   Key3     Key4
# 0        1       7     13  Hrithik
# 1        2       8     14       20
# 2        3  Vishnu     15       21
# 3  Krishan      10     16       22
# 4        5      11     17       23
# 5        6      12  Ankit    Honey

# %% [raw]
# When we use differrent column name in our DataFrame than we need to use left_on and right_on at the same point of a time

# %%
d1 = {"a" : [1,2,3,4,5,6],
      "b" : [7,8,9,10,11,12],
      "c" : [13,14,15,16,17,18],
      "d" : [19,20,21,22,23,24]
     }

# %%
d2 = {"Key1" : [1,2,3,"Krishan",5,6],
      "Key2" : [7,8,"Vishnu",10,11,12],
      "Key3" : [13,14,15,16,17,"Ankit"],
      "Key4" : ["Hrithik",20,21,22,23,"Honey"]
     }

# %%
Df11 = pd.DataFrame(d1 , index= ["0","1","2","3",'4','5'])

# %%
Df12 = pd.DataFrame(d2 , index= ["0","1","Kri","3","4","5"])

# %%
Df11
# Out:
#    a   b   c   d
# 0  1   7  13  19
# 2  2   8  14  20
# 1  3   9  15  21
# 3  4  10  16  22
# 4  5  11  17  23
# 5  6  12  18  24

# %%
Df12
# Out:
#       Key1    Key2   Key3     Key4
# 0        1       7     13  Hrithik
# 1        2       8     14       20
# 2        3  Vishnu     15       21
# 3  Krishan      10     16       22
# 4        5      11     17       23
# 5        6      12  Ankit    Honey

# %%
pd.merge(Df11,Df12, how="left", left_on="d" , right_on = "Key4" )
# Out:
#    a   b   c   d     Key1    Key2 Key3 Key4
# 0  1   7  13  19      NaN     NaN  NaN  NaN
# 1  2   8  14  20        2       8   14   20
# 2  3   9  15  21        3  Vishnu   15   21
# 3  4  10  16  22  Krishan      10   16   22
# 4  5  11  17  23        5      11   17   23
# 5  6  12  18  24      NaN     NaN  NaN  NaN

# %%
pd.merge(Df11,Df12, how="left", left_on="d" , right_on = "Key2" )
# Out:
#    a   b   c   d Key1 Key2 Key3 Key4
# 0  1   7  13  19  NaN  NaN  NaN  NaN
# 1  2   8  14  20  NaN  NaN  NaN  NaN
# 2  3   9  15  21  NaN  NaN  NaN  NaN
# 3  4  10  16  22  NaN  NaN  NaN  NaN
# 4  5  11  17  23  NaN  NaN  NaN  NaN
# 5  6  12  18  24  NaN  NaN  NaN  NaN

# %%
pd.merge(Df12,Df11, how="left", left_on="Key3" , right_on = "a" )
# Out:
#       Key1    Key2   Key3     Key4   a   b   c   d
# 0        1       7     13  Hrithik NaN NaN NaN NaN
# 1        2       8     14       20 NaN NaN NaN NaN
# 2        3  Vishnu     15       21 NaN NaN NaN NaN
# 3  Krishan      10     16       22 NaN NaN NaN NaN
# 4        5      11     17       23 NaN NaN NaN NaN
# 5        6      12  Ankit    Honey NaN NaN NaN NaN

# %%
Df11
# Out:
#    a   b   c   d
# 0  1   7  13  19
# 1  2   8  14  20
# 2  3   9  15  21
# 3  4  10  16  22
# 4  5  11  17  23
# 5  6  12  18  24

# %%
Df12
# Out:
#         Key1    Key2   Key3     Key4
# 0          1       7     13  Hrithik
# 1          2       8     14       20
# Kri        3  Vishnu     15       21
# 3    Krishan      10     16       22
# 4          5      11     17       23
# 5          6      12  Ankit    Honey

# %% [raw]
# when you perform join then one thing you need to keep in mind is
# you should have diff coulmn name in both of the DataFrame
# Than only you will be get any output

# %% [raw]
# Join will checking your indexes in both of the dataframe whether it is same or not
# and than it willl perform join
# if there is no matching than it will return you NaN in Output

# %%
Df11.join(Df12) # by default how wise it will be taking Left join
# Out:
#    a   b   c   d     Key1 Key2   Key3     Key4
# 0  1   7  13  19        1    7     13  Hrithik
# 1  2   8  14  20        2    8     14       20
# 2  3   9  15  21      NaN  NaN    NaN      NaN
# 3  4  10  16  22  Krishan   10     16       22
# 4  5  11  17  23        5   11     17       23
# 5  6  12  18  24        6   12  Ankit    Honey

# %%
Df11.join(Df12 , how="right")
# Out:
#        a     b     c     d     Key1    Key2   Key3     Key4
# 0    1.0   7.0  13.0  19.0        1       7     13  Hrithik
# 1    2.0   8.0  14.0  20.0        2       8     14       20
# Kri  NaN   NaN   NaN   NaN        3  Vishnu     15       21
# 3    4.0  10.0  16.0  22.0  Krishan      10     16       22
# 4    5.0  11.0  17.0  23.0        5      11     17       23
# 5    6.0  12.0  18.0  24.0        6      12  Ankit    Honey

# %%
Df11.join(Df12 , how="outer")
# Out:
#    a   b   c   d     Key1    Key2   Key3     Key4
# 0  1   7  13  19        1       7     13  Hrithik
# 1  2   8  14  20        2       8     14       20
# 2  3   9  15  21        3  Vishnu     15       21
# 3  4  10  16  22  Krishan      10     16       22
# 4  5  11  17  23        5      11     17       23
# 5  6  12  18  24        6      12  Ankit    Honey

# %%
Df11
# Out:
#    a   b   c   d
# 0  1   7  13  19
# 1  2   8  14  20
# 1  3   9  15  21
# 3  4  10  16  22
# 4  5  11  17  23
# 5  6  12  18  24

# %%
Df12
# Out:
#         Key1    Key2   Key3     Key4
# 0          1       7     13  Hrithik
# 1          2       8     14       20
# Kri        3  Vishnu     15       21
# 3    Krishan      10     16       22
# 4          5      11     17       23
# 5          6      12  Ankit    Honey

# %%
Df11.join(Df12 , how="inner")
# Out:
#    a   b   c   d     Key1 Key2   Key3     Key4
# 0  1   7  13  19        1    7     13  Hrithik
# 1  2   8  14  20        2    8     14       20
# 1  3   9  15  21        2    8     14       20
# 3  4  10  16  22  Krishan   10     16       22
# 4  5  11  17  23        5   11     17       23
# 5  6  12  18  24        6   12  Ankit    Honey

# %%
Df11.join(Df12,how = "outer")
# Out:
#        a     b     c     d     Key1    Key2   Key3     Key4
# 0    1.0   7.0  13.0  19.0        1       7     13  Hrithik
# 1    3.0   9.0  15.0  21.0        2       8     14       20
# 2    2.0   8.0  14.0  20.0      NaN     NaN    NaN      NaN
# 3    4.0  10.0  16.0  22.0  Krishan      10     16       22
# 4    5.0  11.0  17.0  23.0        5      11     17       23
# 5    6.0  12.0  18.0  24.0        6      12  Ankit    Honey
# Kri  NaN   NaN   NaN   NaN        3  Vishnu     15       21

# %%
Df11.join(Df12,how = "right")
# Out:
#        a     b     c     d     Key1    Key2   Key3     Key4
# 0    1.0   7.0  13.0  19.0        1       7     13  Hrithik
# 1    3.0   9.0  15.0  21.0        2       8     14       20
# Kri  NaN   NaN   NaN   NaN        3  Vishnu     15       21
# 3    4.0  10.0  16.0  22.0  Krishan      10     16       22
# 4    5.0  11.0  17.0  23.0        5      11     17       23
# 5    6.0  12.0  18.0  24.0        6      12  Ankit    Honey

# %% [raw]
# This is the only differece between Join and merge is
# I am able to do a merge opretion with column value wise but
# when we talking about join opretion with our index match

# %%
pd.concat([Df11,Df12] , axis=0) # Becaouse there is a difference between Coulmn names
# Out:
#        a     b     c     d     Key1    Key2   Key3     Key4
# 0    1.0   7.0  13.0  19.0      NaN     NaN    NaN      NaN
# 1    2.0   8.0  14.0  20.0      NaN     NaN    NaN      NaN
# 2    3.0   9.0  15.0  21.0      NaN     NaN    NaN      NaN
# 3    4.0  10.0  16.0  22.0      NaN     NaN    NaN      NaN
# 4    5.0  11.0  17.0  23.0      NaN     NaN    NaN      NaN
# 5    6.0  12.0  18.0  24.0      NaN     NaN    NaN      NaN
# 0    NaN   NaN   NaN   NaN        1       7     13  Hrithik
# 1    NaN   NaN   NaN   NaN        2       8     14       20
# Kri  NaN   NaN   NaN   NaN        3  Vishnu     15       21
# 3    NaN   NaN   NaN   NaN  Krishan      10     16       22
# 4    NaN   NaN   NaN   NaN        5      11     17       23
# 5    NaN   NaN   NaN   NaN        6      12  Ankit    Honey

# %%
pd.concat([Df11,Df12] , axis=1) # Becaouse there is a difference between Coulmn names
# Out:
#        a     b     c     d     Key1    Key2   Key3     Key4
# 0    1.0   7.0  13.0  19.0        1       7     13  Hrithik
# 1    2.0   8.0  14.0  20.0        2       8     14       20
# 2    3.0   9.0  15.0  21.0      NaN     NaN    NaN      NaN
# 3    4.0  10.0  16.0  22.0  Krishan      10     16       22
# 4    5.0  11.0  17.0  23.0        5      11     17       23
# 5    6.0  12.0  18.0  24.0        6      12  Ankit    Honey
# Kri  NaN   NaN   NaN   NaN        3  Vishnu     15       21

# %%
pd.concat([Df1,Df2] , axis=0)
# Out:
#       Key1    Key2   Key3     Key4
# a        1       7     13       19
# b        2       8     14       20
# c        3       9     15       21
# d        4      10     16       22
# e        5      11     17       23
# f        6      12     18       24
# 0        1       7     13  Hrithik
# 1        2       8     14       20
# 2        3  Vishnu     15       21
# 3  Krishan      10     16       22
# 4        5      11     17       23
# 5        6      12  Ankit    Honey
